# %%
import pandas as pd
df1 = pd.read_csv('https://raw.githubusercontent.com/zoeyyzh/springboard/main/KaggleV2-May-2016.csv',index_col='PatientId')
df1
# Out:
#               AppointmentID Gender          ScheduledDay  \
# PatientId
# 2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...                     ...    ...                   ...
# 2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#                     AppointmentDay  Age      Neighbourhood  Scholarship  \
# PatientId
# 2.987250e+13  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# 5.589978e+14  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0
# ...

# %%
df1.shape
# Out:
# (110527, 13)

# %%
df1['No-show'].nunique()
# Out:
# 2

# %%
#dataset1: 110527 rows and 14 columns, target column is No-show, number of unique values is 2 (No and Yes).

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/zoeyyzh/springboard/main/mushrooms.csv')
df2
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df2.shape
# Out:
# (8124, 23)

# %%
df2['class'].nunique()
# Out:
# 2

# %%
#dataset2: 8124 rows and 23 columns, target column is class, number of unique values is 2 (e and p).

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/zoeyyzh/springboard/main/cardio_train.csv',sep=';', index_col='id')
df3
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# id
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 99993  19240       2     168    76.0    120     80            1     1      1
# 99995  22601       1     158   126.0    140     90            2     2      0
# 99996  19066       2     183   105.0    180     90            3     1      0
# 99998  22431       1     163    72.0    135     80            1     2      0
# 99999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# id
# ...

# %%
df3.shape
# Out:
# (70000, 12)

# %%
df3['cardio'].nunique()
# Out:
# 2

# %%
#dataset3: 70000 rows and 12 columns, target column is cardio, number of unique values is 2 (0 and 1).
